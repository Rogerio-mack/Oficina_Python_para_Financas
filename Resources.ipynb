# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/Oficina_Python_para_Financas/blob/main/Resources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">

# %% [markdown]
# # **Recursos**
#
# ---

# %% [markdown]
# # Quick Start
#
# * [Kaggle Learn](https://www.kaggle.com/learn)
#
# * [W3schools](https://www.w3schools.com/python/default.asp)
#
# * [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb)
#
# * [repl.it](https://replit.com/)

# %% [markdown]
# # Cursos MOOC
#
# * [educative.io](https://www.educative.io/courses/learn-python-3-from-scratch)
#
# * [Coursera Michigan](https://www.coursera.org/specializations/python?irclickid=XSu0tETiDxyNTqYSvDyHPxH9UkASVLwe%3AQc8S00&irgwc=1&utm_medium=partners&utm_source=impact&utm_campaign=3294490&utm_content=b2c#courses)
#
# * [EDX](https://www.edx.org/learn/python)
#
# * [Google](https://developers.google.com/edu/python?hl=pt-br)

# %% [markdown]
# # Livros
#
# <p>
# <!-- <img src="https://covers.oreillystatic.com/images/0636920050896/cat.gif" width="150"/> -->
# <!--<img src="https://user-images.githubusercontent.com/58958893/128409802-170bed67-cb1f-44ef-99c5-4ebdc481e734.png" width="140"/> -->
# <!-- <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/PDSH-cover.png" width="150"/>
# <img src="https://pythonnumericalmethods.berkeley.edu/_images/book_cover.jpg" width="150"/>
# <img src="https://github.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/raw/main/figuras/capas/1.png" width="215"/> -->
# </p>
#
# [McKinney, W. **Python for Data Analysis** (*only Data and Code Notebooks*)](https://github.com/wesm/pydata-book)
#
# [Agarwal, S. **100 Page Python Intro**](https://learnbyexample.github.io/100_page_python_intro/cover.html)
#
#
# [VanderPlas, J. **Python Data Science Handbook**](https://jakevdp.github.io/PythonDataScienceHandbook/)
#
# <br>
#
# <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/PDSH-cover.png" width="160"/>
#
# [Kong, Q.; Siauw, T.; Bayen, A. **Python Programming and Numerical Methods**](https://pythonnumericalmethods.berkeley.edu/notebooks/Index.html)
#
# <br>
#
# <img src="https://pythonnumericalmethods.berkeley.edu/_images/book_cover.jpg" width="150"/>
#
# [Oliveira, R. **Visualizacao de Dados em Python**](https://github.com/Rogerio-mack/Visualizacao-de-Dados-em-Python)
#
# <br>
#
# <img src="https://m.media-amazon.com/images/I/51Beqtk4C-L._SX598_BO1,204,203,200_.jpg" width="150"/>

# %% [markdown]
# # Youtube

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Z1Yd7upQsXY')

# %% [markdown]
# [Playlist](https://www.youtube.com/playlist?list=PLBZBJbE_rGRWeh5mIBhD-hhDwSEDxogDg)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('rfscVS0vtbw')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('7RDu6aoLQz4')
